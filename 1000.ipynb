# %%
# объявление функции вывода случайного числа от 1 до 6 на манер граней кубика
def Diceroll():
    import random
    dice = random.randint(1, 6)
    return dice
# объявление функции броска с добавлением результата в список "бросок"
def Dices():
    global brosok
    for i in range(5):
        raund.append(Diceroll())
# объявление функции для записи "раунда" в переменную "записано" на манер записи на лист бумаги
def Zapisat():
    global zapisano
    global raund
    zapisano += int(sum(raund))
# создаются списки "бросок", "раунд" и переменная "записано"
brosok = []
raund = []
zapisano = 0



# запускается цикл программы до тех пор пока переменная "записано" не будет равна пяти стам
while True:
    if input('Бросить кости? Y/N') == 'y'.lower(): # при условии, что была нажата английская Y
        Dices()
    elif zapisano == 500:  # когда записано 500 - конец
        print('Конец игры')
        break
    else:  # резервный брейк
        break
        
    # вывод результата "броска" и "раунда"
    print(brosok)
    print(raund)

    if input('Записать? Y-да') == 'y'.lower(): # спрашиваем хочет ли игрок записать результат раунда и
        Zapisat()                              #  обращаемся к функции записи, если да, и прерываем цикл, если нет
    else:
        break
    #
    brosok.clear()       # очистка списков "бросок" и "раунд" с выводом переменной "записано" и продолжаем цикл     
    raund.clear()
    print(zapisano)
    continue

#hod является суммарным результатом броска исключительно с учетом "1" "5" и комбинаций

#if zapisat == True

# zapisano += hod
# if zapisano == 555:
#     zapisano = 0
# if zapisano < 69:
#     zapisano = 0
# нажимая кнопку бросить мы получаем шесть кубиков со значением, которое должно записаться 
# в переменную или список, чтобы затем взять конкретный кубик и положить его в другую переменную
# или список, где он/они будут "лежать" и складываться в комбо, после чего мы записываем этот результат
# в переменную "блокнот", где по достижении конкретного значения цикл будет прерываться с 
# выведением сообщения о конце игры
